# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
df = pd.read_csv("owid-covid-data.csv")

# %%
filtro = df['location'] == 'Spain'
df = df.loc[filtro, :]
# Out:
# <AxesSubplot:>
